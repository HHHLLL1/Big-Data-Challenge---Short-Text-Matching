# %%
# 查看当前挂载的数据集目录
# !ls /home/kesci/input/

# %%
# 查看个人持久化工作区文件
# !ls /home/kesci/work/

# %%
# 查看当前kernerl下的package
# !pip list --format=columns

# %%
# 显示cell运行时长
# %load_ext klab-autotime

# %%
import numpy as np
import pandas as pd
import time
import math
from sklearn.model_selection import KFold
from fastText import train_supervised
from sklearn import metrics
from sklearn.linear_model import LinearRegression, LogisticRegression, SGDClassifier
import lightgbm as lgb
import Levenshtein
import gc
from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import TaggedDocument, LabeledSentence, Doc2Vec

# %%
path="/home/kesci/input/bytedance/first-round/"
train = pd.read_csv(path+'train.csv', header=None, chunksize=10000000)
test = pd.read_csv(path+'test.csv', header=None)
pre_df = test[[0, 2]]

# %%
def getvec(x):
    a = 0
    n = 1
    for i in x:
        a += model[i]
        n += 1
        
    return np.array(a)/n

x = 1
for df in train:
    if x != 10:
        print(x)
        x += 1
        continue
    
    print('第%d次处理开始'%x)
    
    y_train = df[4]
    df.drop(4, axis=1, inplace=True)
    df = pd.concat((df, test))
    # del test
    
    

    
    df['cut_review'] = df[1].apply(lambda x: [w for w in x.split(' ') if w != ' '])
    model = Word2Vec(df['cut_review'].values, sg=1, size=100,  window=5,  min_count=0,  negative=3, sample=0.001, hs=1, workers=4)
    x_train_query = []
    x_train_query.append(df.apply(lambda x: getvec(x['cut_review']), axis=1))
    print(x_train_query)
    x_train_query = [i for i in x_train_query[0]]
    x_train_query = np.array(x_train_query)
    np.save('train_test_query.npy', x_train_query)
    
    del 

    
    df['cut_review'] = df[3].apply(lambda x: [w for w in x.split(' ') if w != ' '])
    model = Word2Vec(df['cut_review'].values, sg=1, size=128,  window=5,  min_count=0,  negative=3, sample=0.001, hs=1, workers=4)
    x_train_title = []
    x_train_title.append(df.apply(lambda x: getvec(x['cut_review']), axis=1))
    print(x_train_title)
    x_train_title = [i for i in x_train_title[0]]
    x_train_title = np.array(x_train_title)
    np.save('train_test_title.npy', x_train_title)

    
    print('结束')
    break
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 第10次处理开始
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# [900    [-0.001659443, 0.0006290742, 0.0018024519, -0....
# 901    [-0.001659443, 0.0006290742, 0.0018024519, -0....
# 902    [-0.0014338763, 0.0016518467, -0.00011478895, ...
# 903    [-0.0014338763, 0.0016518467, -0.00011478895, ...
# 904    [-0.0014338763, 0.0016518467, -0.00011478895, ...
# 905    [-0.0014338763, 0.0016518467, -0.00011478895, ...
# 906    [-0.0007017487, -0.0009293647, -0.0021232136, ...
# 907    [-0.0007017487, -0.0009293647, -0.0021232136, ...
# 908    [-0.0007017487, -0.0009293647, -0.0021232136, ...
# 909    [0.0005115638, 0.00076504913, 0.0012857178, 0....
# 910    [0.0005115638, 0.00076504913, 0.0012857178, 0....
# 911    [0.0005115638, 0.00076504913, 0.0012857178, 0....
# ...

# %%
x = [i for i in x_train_query[0]]

# %%
len(x_train_query[0])
# Out:
# 200

# %%
x
# Out:
# array([[-1.6594430e-03,  6.2907417e-04,  1.8024519e-03, ...,
#          1.2453047e-04,  1.9195287e-04, -3.4313803e-04],
#        [-1.6594430e-03,  6.2907417e-04,  1.8024519e-03, ...,
#          1.2453047e-04,  1.9195287e-04, -3.4313803e-04],
#        [-1.4338763e-03,  1.6518467e-03, -1.1478895e-04, ...,
#         -8.3660876e-04,  8.2144636e-04, -4.6807868e-04],
#        ...,
#        [ 6.5914518e-04, -5.0793868e-05,  1.6867215e-03, ...,
#         -9.6649473e-04,  8.7982975e-04,  2.3975309e-03],
#        [ 6.5914518e-04, -5.0793868e-05,  1.6867215e-03, ...,
#         -9.6649473e-04,  8.7982975e-04,  2.3975309e-03],
#        [ 6.5914518e-04, -5.0793868e-05,  1.6867215e-03, ...,
#         -9.6649473e-04,  8.7982975e-04,  2.3975309e-03]], dtype=float32)
